# %% [markdown]
# ## Import Library

# %%
# !pip install google-play-scraper

# %%
from google_play_scraper import app, Sort, reviews, reviews_all
import pandas as pd
import numpy as np

# %%
scrap = reviews_all(
  'com.openai.chatgpt', # App ID
  lang='id', # Language
  country='id', # Country
  sort=Sort.MOST_RELEVANT, # Sort order
  count=10000, # Number of reviews to fetch
  filter_score_with=None # Filter by score (1-5)
)

# %% [markdown]
# ## Cek Data Scrapping

# %%
data = pd.DataFrame(np.array(scrap),columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))
data
# Out:
#                                    reviewId                      userName  \
# 0      5a2b81c9-aff8-46d0-8b2d-dbbc955ee3b5               Pengguna Google
# 1      42efd441-f42e-4270-99cf-01d3d89d48d9               Pengguna Google
# 2      6f6c7e75-c845-47cf-a194-75d2280ca2db               Pengguna Google
# 3      4e80ffa0-f546-4697-b43d-3f2709c27974               Pengguna Google
# 4      ef8cea73-45dd-4254-8d31-cd7a2a5e90d5               Pengguna Google
# ...                                     ...                           ...
# 50090  9c4701d8-53f7-4a65-be34-168c3cde7315                      Depan Ya
# 50091  e04be3c4-bf8c-43fc-9cc6-68e58bb61bc5                 Yerry Suwarna
# 50092  62f767e4-5f76-4987-937f-157dd94a08b7                Fajri Ramadhan
# 50093  72b10b05-fbfd-41fa-8df3-2774df3e6562  24. Nayla Qoni'atun Sholehah
# 50094  239512a3-376a-4355-8e76-34ca890da533                           Usa
#
#                                                userImage  \
# ...

# %% [markdown]
# ## Sortir Kolom yang Dibutuhkan

# %%
data_new = data[['userName', 'content', 'score', 'thumbsUpCount', 'at']]
data_new.head()
# Out:
#           userName                                            content  score  \
# 0  Pengguna Google  Kenapa pas dulu sebelum aku update aku minta k...      3
# 1  Pengguna Google  Aplikasi ChatGPT ini benar-benar luar biasa! R...      5
# 2  Pengguna Google  aplikasinya udah bagus bangett bahkan terlalu ...      5
# 3  Pengguna Google  Sistem nya menjadi error dan tombol "Pembuat U...      4
# 4  Pengguna Google  Hallo gays menurut pribadiku ya, nih apk bagus...      3
#
#    thumbsUpCount                  at
# 0             34 2025-03-29 16:51:02
# 1            434 2025-03-17 03:52:56
# 2            125 2025-03-29 12:41:19
# 3              5 2025-03-29 17:08:47
# 4             37 2025-03-19 21:49:14

# %% [markdown]
# ### Simpan Data ke Format CSV

# %%
data_new.to_csv("/content/drive/MyDrive/submission (1)/scrapped_data.csv", index=False)
